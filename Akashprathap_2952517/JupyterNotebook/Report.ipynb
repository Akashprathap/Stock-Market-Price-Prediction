# %% [markdown]
# # Comparison of Time Series Models Using RMSE value

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1.Federal Bank

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[5.10,5.87,2.03]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - Federal Bank')
plt.legend()

# %% [markdown]
# ## 2.ICICI Bank

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[18.16,17.68,7.45]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - ICICI Bank')
plt.legend()

# %% [markdown]
# ## 3.Canara Bank

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[39.45,36.93,7.45]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - Canara Bank')
plt.legend()

# %% [markdown]
# ## 4.AXIS Bank

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[30.55,31.56,14.50]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - AXIS Bank')
plt.legend()
